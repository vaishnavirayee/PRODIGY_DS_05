# %%
import pandas as pd

# %%
data_filepath = r"C:\Users\kowsh\OneDrive\Desktop\Python\US_Accidents_March23.csv"

# %%
df = pd.read_csv(data_filepath)
df.head(10)
# Out:
#      ID   Source  Severity           Start_Time             End_Time  \
# 0   A-1  Source2         3  2016-02-08 05:46:00  2016-02-08 11:00:00
# 1   A-2  Source2         2  2016-02-08 06:07:59  2016-02-08 06:37:59
# 2   A-3  Source2         2  2016-02-08 06:49:27  2016-02-08 07:19:27
# 3   A-4  Source2         3  2016-02-08 07:23:34  2016-02-08 07:53:34
# 4   A-5  Source2         2  2016-02-08 07:39:07  2016-02-08 08:09:07
# 5   A-6  Source2         3  2016-02-08 07:44:26  2016-02-08 08:14:26
# 6   A-7  Source2         2  2016-02-08 07:59:35  2016-02-08 08:29:35
# 7   A-8  Source2         3  2016-02-08 07:59:58  2016-02-08 08:29:58
# 8   A-9  Source2         2  2016-02-08 08:00:40  2016-02-08 08:30:40
# 9  A-10  Source2         3  2016-02-08 08:10:04  2016-02-08 08:40:04
#
#    Start_Lat  Start_Lng  End_Lat  End_Lng  Distance(mi)  ... Roundabout  \
# 0  39.865147 -84.058723      NaN      NaN          0.01  ...      False
# 1  39.928059 -82.831184      NaN      NaN          0.01  ...      False
# 2  39.063148 -84.032608      NaN      NaN          0.01  ...      False
# 3  39.747753 -84.205582      NaN      NaN          0.01  ...      False
# 4  39.627781 -84.188354      NaN      NaN          0.01  ...      False
# 5  40.100590 -82.925194      NaN      NaN          0.01  ...      False
# 6  39.758274 -84.230507      NaN      NaN          0.00  ...      False
# 7  39.770382 -84.194901      NaN      NaN          0.01  ...      False
# 8  39.778061 -84.172005      NaN      NaN          0.00  ...      False
# 9  40.100590 -82.925194      NaN      NaN          0.01  ...      False
#
#   Station   Stop Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0   False  False           False          False        False          Night
# 1   False  False           False          False        False          Night
# 2   False  False           False           True        False          Night
# 3   False  False           False          False        False          Night
# 4   False  False           False           True        False            Day
# 5   False  False           False          False        False            Day
# 6   False  False           False          False        False            Day
# 7   False  False           False          False        False            Day
# 8   False  False           False          False        False            Day
# 9   False  False           False          False        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0          Night             Night                 Night
# 1          Night             Night                   Day
# 2          Night               Day                   Day
# 3            Day               Day                   Day
# 4            Day               Day                   Day
# 5            Day               Day                   Day
# 6            Day               Day                   Day
# 7            Day               Day                   Day
# 8            Day               Day                   Day
# 9            Day               Day                   Day
#
# [10 rows x 46 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Source', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat',
#        'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)', 'Description',
#        'Street', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
print("Number of columns: ",len(df.columns))
print("number of rows: ",len(df))
# Out:
# Number of columns:  46
# number of rows:  7728394

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7728394 entries, 0 to 7728393
# Data columns (total 46 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   Severity               int64
#  3   Start_Time             object
#  4   End_Time               object
#  5   Start_Lat              float64
#  6   Start_Lng              float64
#  7   End_Lat                float64
#  8   End_Lng                float64
#  9   Distance(mi)           float64
#  10  Description            object
#  11  Street                 object
#  12  City                   object
#  13  County                 object
#  14  State                  object
#  15  Zipcode                object
#  16  Country                object
#  17  Timezone               object
#  18  Airport_Code           object
#  19  Weather_Timestamp      object
#  20  Temperature(F)         float64
#  21  Wind_Chill(F)          float64
#  22  Humidity(%)            float64
#  23  Pressure(in)           float64
#  24  Visibility(mi)         float64
#  25  Wind_Direction         object
#  26  Wind_Speed(mph)        float64
#  27  Precipitation(in)      float64
#  28  Weather_Condition      object
#  29  Amenity                bool
#  30  Bump                   bool
#  31  Crossing               bool
#  32  Give_Way               bool
#  33  Junction               bool
#  34  No_Exit                bool
#  35  Railway                bool
#  36  Roundabout             bool
#  37  Station                bool
#  38  Stop                   bool
#  39  Traffic_Calming        bool
#  40  Traffic_Signal         bool
#  41  Turning_Loop           bool
#  42  Sunrise_Sunset         object
#  43  Civil_Twilight         object
#  44  Nautical_Twilight      object
#  45  Astronomical_Twilight  object
# dtypes: bool(13), float64(12), int64(1), object(20)
# memory usage: 2.0+ GB

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  7.728394e+06  7.728394e+06  7.728394e+06  4.325632e+06  4.325632e+06
# mean   2.212384e+00  3.620119e+01 -9.470255e+01  3.626183e+01 -9.572557e+01
# std    4.875313e-01  5.076079e+00  1.739176e+01  5.272905e+00  1.810793e+01
# min    1.000000e+00  2.455480e+01 -1.246238e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.339963e+01 -1.172194e+02  3.346207e+01 -1.177543e+02
# 50%    2.000000e+00  3.582397e+01 -8.776662e+01  3.618349e+01 -8.802789e+01
# 75%    2.000000e+00  4.008496e+01 -8.035368e+01  4.017892e+01 -8.024709e+01
# max    4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)  Temperature(F)  Wind_Chill(F)   Humidity(%)  \
# count  7.728394e+06    7.564541e+06   5.729375e+06  7.554250e+06
# mean   5.618423e-01    6.166329e+01   5.825105e+01  6.483104e+01
# std    1.776811e+00    1.901365e+01   2.238983e+01  2.282097e+01
# min    0.000000e+00   -8.900000e+01  -8.900000e+01  1.000000e+00
# 25%    0.000000e+00    4.900000e+01   4.300000e+01  4.800000e+01
# 50%    3.000000e-02    6.400000e+01   6.200000e+01  6.700000e+01
# 75%    4.640000e-01    7.600000e+01   7.500000e+01  8.400000e+01
# max    4.417500e+02    2.070000e+02   2.070000e+02  1.000000e+02
#
#        Pressure(in)  Visibility(mi)  Wind_Speed(mph)  Precipitation(in)
# count  7.587715e+06    7.551296e+06     7.157161e+06       5.524808e+06
# mean   2.953899e+01    9.090376e+00     7.685490e+00       8.407210e-03
# std    1.006190e+00    2.688316e+00     5.424983e+00       1.102246e-01
# min    0.000000e+00    0.000000e+00     0.000000e+00       0.000000e+00
# 25%    2.937000e+01    1.000000e+01     4.600000e+00       0.000000e+00
# 50%    2.986000e+01    1.000000e+01     7.000000e+00       0.000000e+00
# 75%    3.003000e+01    1.000000e+01     1.040000e+01       0.000000e+00
# max    5.863000e+01    1.400000e+02     1.087000e+03       3.647000e+01

# %%
len(df.select_dtypes(['int64', 'float64']).columns)
# Out:
# 13

# %%
df.isnull().sum()
# Out:
# ID                             0
# Source                         0
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  3402762
# End_Lng                  3402762
# Distance(mi)                   0
# Description                    5
# Street                     10869
# City                         253
# County                         0
# State                          0
# Zipcode                     1915
# Country                        0
# Timezone                    7808
# Airport_Code               22635
# Weather_Timestamp         120228
# Temperature(F)            163853
# Wind_Chill(F)            1999019
# Humidity(%)               174144
# Pressure(in)              140679
# Visibility(mi)            177098
# Wind_Direction            175206
# Wind_Speed(mph)           571233
# Precipitation(in)        2203586
# Weather_Condition         173459
# Amenity                        0
# Bump                           0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Traffic_Calming                0
# Traffic_Signal                 0
# Turning_Loop                   0
# Sunrise_Sunset             23246
# Civil_Twilight             23246
# Nautical_Twilight          23246
# Astronomical_Twilight      23246
# dtype: int64

# %%
import pandas as pd

# Sample data
data = {
    'Start_Time': ['2024-01-01 00:00:00', None, '2024-01-01 02:00:00'],
    'City': ['CityA', 'CityB', None],
    'Latitude': [34.0522, 36.7783, None],
    'Longitude': [-118.2437, None, -74.0060]
}

df = pd.DataFrame(data)
missing_data = df.isna().sum()

print(missing_data)
# Out:
# Start_Time    1
# City          1
# Latitude      1
# Longitude     1
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)*100./len(df)
# Out:
# Start_Time    33.333333
# City          33.333333
# Latitude      33.333333
# Longitude     33.333333
# dtype: float64

# %%
import pandas as pd
missing_data = df.isnull().sum() / len(df) * 100
sorted_missing_data = missing_data.sort_values(ascending=False)

print(sorted_missing_data)
# Out:
# Start_Time    33.333333
# City          33.333333
# Latitude      33.333333
# Longitude     33.333333
# dtype: float64

# %%
type(missing_data)
# Out:
# pandas.core.series.Series

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Start_Time': ['2024-01-01 00:00:00', None, '2024-01-01 02:00:00'],
    'City': ['CityA', 'CityB', None],
    'Latitude': [34.0522, 36.7783, None],
    'Longitude': [-118.2437, None, -74.0060]
}
df = pd.DataFrame(data)

missing_data = df.isna().sum()
missing_data.plot(kind='bar', figsize=(10, 6))  
plt.xlabel('Columns')
plt.ylabel('Number of Missing Values')
plt.title('Number of Missing Values in Each Column')
plt.xticks(rotation=45)  
plt.grid(axis='y')  
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = {
    'Start_Time': ['2024-01-01 00:00:00', None, '2024-01-01 02:00:00'],
    'City': ['CityA', 'CityB', None],
    'Latitude': [34.0522, 36.7783, None],
    'Longitude': [-118.2437, None, -74.0060]
}
df = pd.DataFrame(data)

missing_data = df.isna().sum()

if not missing_data.empty:
    missing_data[missing_data != 0].plot(kind='barh')
    plt.xlabel('Number of Missing Values')
    plt.title('Columns with Missing Values')
    plt.show()
else:
    print("No missing values found.")

# %%
df.columns
# Out:
# Index(['Start_Time', 'City', 'Latitude', 'Longitude'], dtype='object')

# %%
df.City.unique()
# Out:
# array(['CityA', 'CityB', None], dtype=object)

# %%
cities=df.City.unique()
len(cities)
# Out:
# 3

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident[:20]
# Out:
# City
# CityA    1
# CityB    1
# Name: count, dtype: int64

# %%
'Dallas' in cities
# Out:
# False

# %%
print(cities_by_accident.index)
# Out:
# Index(['CityA', 'CityB'], dtype='object', name='City')

# %%
cities_by_accident[:20].plot(kind='barh')
# Out:
# <Axes: ylabel='City'>

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %%
import pandas as pd
cities_by_accident = pd.Series([100, 200, 150, 300, 250], index=['CityA', 'CityB', 'CityC', 'CityD', 'CityE'])
sns.displot(cities_by_accident, kde=False) 
plt.xlabel('Accidents')
plt.ylabel('Count')
plt.title('Histogram of Accidents by City')
plt.show()

# %%
accident_counts = df.groupby('City').size()
high_accident_cities = accident_counts[accident_counts > 1000]
print(high_accident_cities)
# Out:
# Series([], dtype: int64)

# %%
low_accident_cities = accident_counts[accident_counts < 1001]
print(low_accident_cities)
# Out:
# City
# CityA    1
# CityB    1
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
high_accident_cities = pd.Series([1200, 1500, 1800, 2000, 2200], index=['CityA', 'CityB', 'CityC', 'CityD', 'CityE'])
if not high_accident_cities.empty and high_accident_cities.notna().all():
    # Plotting with histplot
    sns.histplot(high_accident_cities, kde=False)
    plt.xlabel('Cities')
    plt.ylabel('Accident Count')
    plt.title('Accident Counts in High Accident Cities')
    plt.xticks(rotation=45) 
    plt.show()
else:
    print("The dataset is empty or contains invalid values.")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
low_accident_cities = pd.Series([10, 20, 15, 5, 25], index=['CityX', 'CityY', 'CityZ', 'CityW', 'CityV'])

if not low_accident_cities.empty and low_accident_cities.notna().all():
    sns.histplot(low_accident_cities, kde=False)
    plt.xlabel('Cities')
    plt.ylabel('Accident Count')
    plt.title('Accident Counts in Low Accident Cities')
    plt.xticks(rotation=45)  
    plt.show()
else:
    print("The dataset is empty or contains invalid values.")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
low_accident_cities = pd.Series([10, 20, 15, 5, 25], index=['CityX', 'CityY', 'CityZ', 'CityW', 'CityV'])
if not low_accident_cities.empty and low_accident_cities.notna().all():
    sns.histplot(low_accident_cities, log_scale=True)
    plt.xlabel('Cities')
    plt.ylabel('Accident Count')
    plt.title('Accident Counts in Low Accident Cities')
    plt.xticks(rotation=45)
    plt.show()
else:
    print("The dataset is empty or contains invalid values.")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
high_accident_cities = pd.Series([1200, 1500, 1800, 2000, 2200], index=['CityA', 'CityB', 'CityC', 'CityD', 'CityE'])
if not high_accident_cities.empty and high_accident_cities.notna().all():
    sns.histplot(high_accident_cities, log_scale=True)
    plt.xlabel('Cities')
    plt.ylabel('Accident Count')
    plt.title('Accident Counts in High Accident Cities')
    plt.xticks(rotation=45)  
    plt.show()
else:
    print("The dataset is empty or contains invalid values.")

# %%
import pandas as pd
data = {
    'City': ['CityA', 'CityB', 'CityA', 'CityC', 'CityB', 'CityA', 'CityB', 'CityC', 'CityD', 'CityE'] * 200,
    'AccidentID': range(2000)
}
df = pd.DataFrame(data)

accident_counts = df.groupby('City').size()

high_accident_cities = accident_counts[accident_counts > 1000]
print("Cities with over 1,000 accidents:")
print(high_accident_cities)
low_accident_cities = accident_counts[accident_counts < 1001]
print("\nCities with less than 1,001 accidents:")
print(low_accident_cities)
# Out:
# Cities with over 1,000 accidents:
# Series([], dtype: int64)
#
# Cities with less than 1,001 accidents:
# City
# CityA    600
# CityB    600
# CityC    400
# CityD    200
# CityE    200
# dtype: int64

# %%
cities_by_accident[cities_by_accident == 1]
# Out:
# Series([], dtype: int64)

# %%
data = {
    ' Start_Time ': ['2024-01-01 00:00:00', '2024-01-01 01:00:00', '2024-01-01 02:00:00'],
    'City': ['CityA', 'CityB', 'CityC']
}

df = pd.DataFrame(data)
print(df.columns)
df.columns = df.columns.str.strip()
start_time_iloc = df.iloc[0]['Start_Time']
print("Using iloc:", start_time_iloc)

start_time_bracket = df['Start_Time'].iloc[0]
print("Using bracket notation:", start_time_bracket)


start_time_at = df.at[0, 'Start_Time']
print("Using at:", start_time_at)
# Out:
# Index([' Start_Time ', 'City'], dtype='object')
# Using iloc: 2024-01-01 00:00:00
# Using bracket notation: 2024-01-01 00:00:00
# Using at: 2024-01-01 00:00:00

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Start_Time': ['2024-01-01 00:00:00', '2024-01-01 01:00:00', '2024-01-01 02:00:00', '2024-01-02 00:00:00', '2024-01-02 01:00:00', '2024-01-02 02:00:00'],
    'City': ['CityA', 'CityB', 'CityC', 'CityA', 'CityB', 'CityC']
}

df = pd.DataFrame(data)

df['Start_Time'] = pd.to_datetime(df['Start_Time'])

df['Hour'] = df['Start_Time'].dt.hour
df['Day'] = df['Start_Time'].dt.day_name()

hourly_data = df.groupby(['Day', 'Hour']).size().unstack().fillna(0)

hourly_data = hourly_data.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

plt.figure(figsize=(14, 8))
sns.heatmap(hourly_data, cmap="YlGnBu", cbar_kws={'label': 'Number of Accidents'})
plt.title('Hourly Distribution of Accidents for Each Day of the Week')
plt.xlabel('Hour of the Day')
plt.ylabel('Day of the Week')
plt.show()

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (0.16.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: branca>=0.6.0 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from folium) (2024.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kowsh\appdata\local\programs\python\python312\lib\site-packages (from requests->folium) (2024.2.2)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
high_accident_cities = pd.Series([1200, 1500, 1800, 2000, 2200], index=['CityA', 'CityB', 'CityC', 'CityD', 'CityE'])
population = pd.Series([1000000, 500000, 800000, 1200000, 300000], index=['CityA', 'CityB', 'CityC', 'CityD', 'CityE'])
if not high_accident_cities.empty and high_accident_cities.notna().all() and \
   not population.empty and population.notna().all():
    plt.figure(figsize=(10, 6))  # Set figure size
    sns.scatterplot(x=population, y=high_accident_cities, s=100, color='#4C72B0', alpha=0.8, edgecolor='black', linewidth=0.5)
    plt.xlabel('Population', fontsize=14, fontweight='bold')  
    plt.ylabel('Accident Count', fontsize=14, fontweight='bold') 
    plt.title('Scatter Plot of Accident Counts vs Population', fontsize=16, fontweight='bold')  
    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)
    plt.grid(True)
    plt.tight_layout() 
    plt.show()
else:
    print("The datasets are empty or contain invalid values.")

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = {
    'State': ['NY', 'CA', 'TX', 'FL', 'IL', 'PA', 'OH', 'GA', 'NC', 'MI', 
              'NJ', 'VA', 'WA', 'MA', 'AZ', 'TN', 'IN', 'MO', 'MD', 'WI'],
    'Count': [25, 20, 15, 10, 8, 7, 6, 5, 4, 3, 
              3, 2, 2, 2, 1, 1, 1, 1, 1, 1]
}
df = pd.DataFrame(data)
plt.figure(figsize=(10, 10))  

plt.pie(df['Count'], labels=df['State'], autopct='%1.1f%%', startangle=140)

plt.title('Distribution of States', fontsize=16, fontweight='bold')
plt.tight_layout()
plt.show()
